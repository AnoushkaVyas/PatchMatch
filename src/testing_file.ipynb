# %%
import numpy as np
from patchmatch import PatchMatch
import cv2
from helper_functions import *

# %%
pm = PatchMatch(5,5)
a = read_image("../images/a.png")
b = read_image("../images/b.png")
plot_images([a,b], (1,2))

# %%
dist, loc = pm.run(a,b, vary_size=False)
# Out:
# Image shape: (89, 99)
# 100%|██████████| 5/5 [00:09<00:00,  1.85s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]Image shape: (179, 199)
# 100%|██████████| 5/5 [00:37<00:00,  7.45s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]Image shape: (358, 399)
# 100%|██████████| 5/5 [02:34<00:00, 30.85s/it]

# %%
plt.imshow(dist, 'gray'); plt.show()

# %%
print(a.shape)
reconstructted_image = np.zeros(a.shape)
for i in range(loc.shape[0]):
    for j in range(loc.shape[1]):
        reconstructted_image[i,j,:] = b[loc[i,j,0],loc[i,j,1],:]
    reconstructted_image = reconstructted_image.astype(int)

plt.imshow(reconstructted_image); plt.show()
# Out:
# (358, 399, 3)

# %%
a = read_image("../images/test1a.png")
b = read_image("../images/test1b.png")
plot_images([a,b], (1,2))

# %%
dist, loc = pm.run(b,a, vary_size=False)
# Out:
# Image shape: (77, 115)
#  80%|████████  | 4/5 [00:07<00:01,  1.78s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1aa38508bc55> in <module>
# ----> 1 dist, loc = pm.run(b,a)
#
# ~/project-strawhat/src/patchmatch.py in run(self, image, image_2, vary_size)
#      96                     for j in range (image.shape[1] - self.patch_size):
#      97                         self.propagation(image, image_2, [i,j], is_even)
# ---> 98                         self.random_search(image, image_2, [i,j])
#      99
#     100         return self.nearest_patch_distance, self.nearest_patch_location
#
# ~/project-strawhat/src/patchmatch.py in random_search(self, image, image2, patch_index, alpha)
#     148         patch_index = np.array(patch_index)
#     149         Ri = np.random.uniform(-1,1,(1,2)); Ri = Ri[0]
# --> 150         random_search_magnitude = np.max(image2.shape)*alpha
#     151         random_search_distance = np.ceil(random_search_magnitude*Ri).astype(int)
#     152         current_nearest_patch_location = deepcopy(self.nearest_patch_location[patch_index[0], patch_index[1]])
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~/anaconda3/envs/random/lib/python3.8/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2665     5
#    2666     """
# -> 2667     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2668                           keepdims=keepdims, initial=initial, where=where)
#    2669
#
# ~/anaconda3/envs/random/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      71
#      72
# ---> 73 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      74     passkwargs = {k: v for k, v in kwargs.items()
#      75                   if v is not np._NoValue}
#
# KeyboardInterrupt:

# %%
plt.imshow(dist, 'gray'); plt.show()
print(a.shape)
reconstructted_image = np.zeros(a.shape)
for i in range(loc.shape[0]):
    for j in range(loc.shape[1]):
        reconstructted_image[i,j,:] = b[loc[i,j,0],loc[i,j,1],:]
    reconstructted_image = reconstructted_image.astype(int)

plt.imshow(reconstructted_image); plt.show()
# Out:
# (310, 460, 4)
